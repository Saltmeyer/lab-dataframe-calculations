# %%
import pandas as pd
import numpy as np

# %%
pokemon = pd.read_csv('pokemon.csv')

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
a = 'Hello where am I'
print(a.rsplit('where'))
# Out:
# ['Hello ', ' am I']

# %%
a.apply(mega)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-5ebfd1006229> in <module>
# ----> 1 a.apply(mega)
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
def mega(text):
      
    if "Mega" in text:
        split = text.split('Mega',1)
        return split
    else:
        return text

# %%
pokemon = pokemon.apply(mega)

# %%
pokemon['Type 1'].dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-40-a0cf9fdd7bfc> in <module>
# ----> 1 pokemon['Type 1'].dtypes()
#
# TypeError: 'numpy.dtype[object_]' object is not callable

# %%
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
pokemon['Combo Type'] = pokemon[['Type 1', 'Type 2']].agg('-'.join, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-ab12cb67ef93> in <module>
# ----> 1 pokemon['Combo Type'] = pokemon[['Type 1', 'Type 2']].agg('-'.join, axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in aggregate(self, func, axis, *args, **kwargs)
#    7584             raise exc from err
#    7585         if result is None:
# -> 7586             return self.apply(func, axis=axis, args=args, **kwargs)
#    7587
#    7588         if relabeling:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7766             kwds=kwds,
#    7767         )
# -> 7768         return op.get_result()
#    7769
#    7770     def applymap(self, func, na_action: Optional[str] = None) -> DataFrame:
#
# ~\anaconda3\lib\site-packages\pandas\core\apply.py in get_result(self)
# ...
